# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/steffen/.cache/kagglehub/datasets/gpiosenka/cards-image-datasetclassification/2.archive...
# 100%|██████████| 385M/385M [00:20<00:00, 19.9MB/s]
# Extracting files...
# Path to dataset files: /home/steffen/.cache/kagglehub/datasets/gpiosenka/cards-image-datasetclassification/versions/2
